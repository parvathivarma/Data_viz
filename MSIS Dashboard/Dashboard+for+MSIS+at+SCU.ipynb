# %% [markdown]
#                                     Lab Session - 4
#                                     MSIS Dashboard
#
#       Task: Create MSIS Dashboard for Santa Clara University that will help students and recruiters make decisions.
#
#       Steps: We extract data from various websites such as Payscale.com, scu.edu and other web pages where we get information on University/program ranking, job prospects, cost of living, tution fee etc.
#
#      I have explained the claim, data, qualifier, warrant, backing and reservation underneath each graph in each section of this notebook.

# %% [markdown]
# # CLAIM: Santa Clara university is very good for pursuing MSIS Degree
#   QUALIFIER: I have taken Silicon Valley universities to compare the results (Applies to all the analysis done in this iteration)

# %%
from bs4 import BeautifulSoup

import requests

req  = requests.get("https://www.collegefactual.com/colleges/santa-clara-university/paying-for-college/room-and-board/")

soup = BeautifulSoup(req.content, 'html.parser')

table = soup.find_all('table')

table = soup.find_all('table')[2]

rows = table.find_all('tr')[2:]

# %%
for row in rows:
    cols = row.find_all('td')

data = {
    'Expense' : [],
    'On Campus' : [],
    'Off Campus' : []
  }

# %%
for row in rows:
    cols = row.find_all('td')    
    data['Expense'].append( cols[0].get_text() )
    data['On Campus'].append( cols[1].get_text() )
    data['Off Campus'].append( cols[2].get_text() )

# %%
import pandas as pd;
Expense_Scu = pd.DataFrame( data )

Expense_Scu.to_csv("Expense_scu.csv")

# %% [markdown]
# Similary, we can extract the living expense for few other universities in west coast for comparison purpose

# %%
# Living expense for SJSU

req  = requests.get("https://www.collegefactual.com/colleges/san-jose-state-university/paying-for-college/room-and-board/")

soup = BeautifulSoup(req.content, 'html.parser')

table = soup.find_all('table')

table = soup.find_all('table')[2]

rows = table.find_all('tr')[2:]

# %%
for row in rows:
    cols = row.find_all('td')

data = {
    'Expense' : [],
    'On Campus' : []
  }

# %%
for row in rows:
    cols = row.find_all('td')    
    data['Expense'].append( cols[0].get_text() )
    data['On Campus'].append( cols[1].get_text() )

# %%
import pandas as pd;
Expense_Sjsu = pd.DataFrame( data )

Expense_Sjsu.to_csv("Expense_sjsu.csv")

# %% [markdown]
# Also, we extract for other universities by replacing the URL with the university URL

# %% [markdown]
# <img src = "cost of living.png">

# %% [markdown]
#                       Data: https://www.collegefactual.com/colleges/santa-clara-university/paying-for-college/room-and-board/
#                        Description: We find that the above graph does not support the claim as "cost of living" alone cannot be a measure in proving our claim. In the graph, I have taken the cost of living by extracting the tution fee (That includes the number of units and fee for each unit) and the rent expenses along with food under the category of (Room and Board).
#
#                         Warrant: If the living expense is high, it shows that the it will be difficult pursue student life at SCU.
#                         Backing: http://www.areavibes.com/santa+clara-ca/cost-of-living/
#                         Reservation: Number of units (courses) offered at Santa Clara is way more than other universities and hence the high Tution fee: https://www.scu.edu/business/ms-information-systems/curriculum/
#
#                         Disadvantage: It does not support the claim as mentioned in the description
#                         Advantage: It is also a factor to consider admission in one university

# %% [markdown]
# # ranking of all universities

# %%
req  = requests.get("https://www.scu.edu/business/ms-information-systems/prospective-students/class-profile/")

# %%
soup = BeautifulSoup(req.content, 'html.parser')
import json
script =  soup.find_all('p')
linkData = script


var1 = linkData[1].text
var2 = linkData[2].text
var3 = linkData[3].text
var4 = linkData[4].text
var5 = linkData[5].text
var6 = linkData[6].text
var7 = linkData[7].text
var8 = linkData[8].text
var9 = linkData[9].text
var10 = linkData[10].text
var11 = linkData[11].text

# Approach 1: Just print variables comma-separated
print (var1,var2,var3,var4,var5,var6,var7,var8,var9,var10,var11)
# Out:
#                       Women : 51% Average age : 26 Multilingual :  89% Average undergraduate GPA  3.2 Average GMAT  650 Average GRE  308 % holding graduate degrees  20% Average work experience :  2.3 years Employed at time of admission : 66% Selected hiring companies :  Apple, Cisco, Ernst & Young, Facebook, NetApp, NVIDIA, Symantec, Twitter

# %%
import pandas as pd
url = 'http://higheredublog.com/top-universities-for-ms-in-mis-in-usa/'
data = pd.read_html(url, header = 0)

data1 = data[0]
data1.head()

data1.columns = ['RANKING', 'UNIVERSITY', 'PROGRAM']

df = pd.DataFrame(data1)

df.to_csv('Ranking_universities.csv', index=False, encoding='utf-8')

# %% [markdown]
# <img src = "MSIS Profile.png">

# %% [markdown]
# Data: http://higheredublog.com/top-universities-for-ms-in-mis-in-usa/
#
# Desription: The MSIS profile gives us the overall ranking of SCU MSIS program in US and also shows the demographics of the university. In the data, we can see the average work experience of a person pursuing the master's degree and their GPA.
#
# Warrant: Equal propotion of men and women in the class and mix of culture within the university can give more exposure to students, better global engagement and wider networks.
#
# Backing: http://www.independent.co.uk/student/career-planning/getting-job/its-good-to-talk-how-being-multi-lingual-can-boost-your-career-969235.html
#
# Reservation: I am not able to find any reservation as this is just a profile.
#
# Advantage: Gives a clear idea on the ranking and the culture of the university in a go
# Disadvantage: Want to compare how it is better option when compared to other universities

# %% [markdown]
# We will now extract the MSIS payscale for SCU graduates

# %%
response3 = requests.get("https://www.payscale.com/research/US/Degree=Master_of_Information_Science_(MIS)/Salary")
html3 = response3.content
soup = BeautifulSoup(html3, 'html.parser')
soup.prettify(formatter=lambda s: s.replace(u'\xa0', ' '))
#print (soup.prettify())
pay = soup.find_all("div", {"class":"bar-chart-bootstrap"})
for i in pay:
   print(i.text)
pay1=[]
for item in pay:
   pay1.append(item.text)
# Out:
# JobAverageMinMaxSoftware Engineer111 profiles$86,916$65K$122KData Analyst83 profiles$63,839$46K$82KBusiness Analyst, IT69 profiles$67,970$51K$86KGet a personalized salary report!Location:Years in Field/Career:Years in Field/Career:United States (change)Information Technology (IT) Manager67 profiles$100,541$65K$131KProject Manager, Information Technology (IT)54 profiles$90,546$64K$119KSoftware Developer47 profiles$72,474$58K$104KInformation Technology (IT) Director46 profiles$118,960$73K$171KSee all employers for Master of Information Science (MIS) »See all employers for Master of Information Science (MIS) »Currency: USDUpdated: 11 Oct 2017Individuals Reporting: 2,485View Table

# %% [markdown]
# <img src = "Average Salary.png">

# %% [markdown]
# Data: https://www.payscale.com/research/US/Degree=Master_of_Information_Science_(MIS)/Salary
#
# Description of the graph: The graph shows that Software Developers are one the highest paid jobs for MSIS students.
# I wanted to show the average salary in silicon valley and compare it with the salary earned by MSIS graduates. This will be the road map. However, I have collected the data and it shows that SCU gradutes in these role earn more than average pay scale. I will be including the graph in the next iteration.
#
# Warrant: Higher job prospects are more desirable and hence it strongly supports the claim.
#
# Backing: https://www.scu.edu/news-and-events/press-releases/2016/april-2016/santa-clara-university-ranks-high-on-payscale-college-roi-report.html
#
# Reservation: The average salary is being compared with just silicon valley universities, but when taken at a higher scope and including the graduates from ivey league colleges, the average salary for scu graduates may become lower.
#
# Future scope: As explained in the description, I would like to add average payscale in Silicon valley which can provide a better picture.

# %% [markdown]
# The payscale can be again extracted for different universities by modifying the URL

# %% [markdown]
# # Acceptance RATE at different california Universities

# %%
response3 = requests.get("http://www.acceptancerate.com/california")
html3 = response3.content
soup = BeautifulSoup(html3, 'html.parser')
#soup.prettify(formatter=lambda s: s.replace(u'\xa0', ' '))
print (soup.prettify())
acc_rate= soup.find_all("table", "table table-hover table-condensed listing_table")
for i in acc_rate:
    print(i.text)
acc=[]
for mytable in acc_rate:
    acc_body = mytable.find('tbody')
    try:
        acc_rows = acc_body.find_all('tr')
        for tr in acc_rows:
            acc_cols = tr.find_all('td')
            name = acc_cols[1].text
            applicants = acc_cols[2].string
            admitted = acc_cols[3].string
            accept_rate = acc_cols[4].string
            record = (name, applicants, admitted, accept_rate)
            print(record)
    except:
        print("no tbody")
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]><html class="ie ie6" lang="en-US"> <![endif]-->
# <!--[if IE 7 ]><html class="ie ie7" lang="en-US"> <![endif]-->
# <!--[if IE 8 ]><html class="ie ie8" lang="en-US"> <![endif]-->
# <!--[if IE 9 ]><html class="ie ie9" lang="en-US"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <link href="http://www.acceptancerate.com/wp-content/cache/minify/000000/a8ca8/default.include.364c6f.css" media="all" rel="stylesheet" type="text/css"/>
#   <script src="http://www.acceptancerate.com/wp-content/cache/minify/000000/a8ca8/default.include.091c5c.js" type="text/javascript">
#   </script>
#   <title itemprop="name">
#    Acceptance Rate for Colleges in California | AcceptanceRate.com
#   </title>
#   <meta content="California college and university acceptance rate information, GPA averages, and SAT / ACT scores for four year degree granting institutions." itemprop="description" name="description"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <link href="http://www.acceptancerate.com/wp-content/themes/Child-Theme/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="http://www.acceptancerate.com/xmlrpc.php" rel="pingback"/>
#   <link href="http://www.acceptancerate.com/feed" rel="alternate" title="AcceptanceRate.com" type="application/rss+xml"/>
#   <link href="http://www.acceptancerate.com/feed/atom" rel="alternate" title="AcceptanceRate.com" type="application/atom+xml"/>
#   <script type="text/javascript">
#    /*<![CDATA[*/window._wpemojiSettings={"baseUrl":"http:\/\/s.w.org\/images\/core\/emoji\/72x72\/","ext":".png","source":{"concatemoji":"http:\/\/www.acceptancerate.com\/wp-includes\/js\/wp-emoji-release.min.js?ver=4.3.11"}};!function(a,b,c){function d(a){var c=b.createElement("canvas"),d=c.getContext&&c.getContext("2d");return d&&d.fillText?(d.textBaseline="top",d.font="600 32px Arial","flag"===a?(d.fillText(String.fromCharCode(55356,56812,55356,56807),0,0),c.toDataURL().length>3e3):(d.fillText(String.fromCharCode(55357,56835),0,0),0!==d.getImageData(16,16,1,1).data[0])):!1}function e(a){var c=b.createElement("script");c.src=a,c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var f,g;c.supports={simple:d("simple"),flag:d("flag")},c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.simple&&c.supports.flag||(g=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",g,!1),a.addEventListener("load",g,!1)):(a.attachEvent("onload",g),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),f=c.source||{},f.concatemoji?e(f.concatemoji):f.wpemoji&&f.twemoji&&(e(f.twemoji),e(f.wpemoji)))}(window,document,window._wpemojiSettings);/*]]>*/
#   </script>
#   <style type="text/css">
#    img.wp-smiley,img.emoji{display:inline !important;border:none !important;box-shadow:none !important;height:1em !important;width:1em !important;margin:0 .07em !important;vertical-align:-0.1em !important;background:none !important;padding:0 !important}
#   </style>
#   <link href="//netdna.bootstrapcdn.com/font-awesome/3.2.1/css/font-awesome.css?ver=3.2.1" id="font-awesome-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//fonts.googleapis.com/css?family=Droid+Serif&amp;subset=latin" id="options_typography_Droid+Serif-css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="//fonts.googleapis.com/css?family=Open+Sans&amp;subset=latin" id="options_typography_Open+Sans-css" media="all" rel="stylesheet" type="text/css"/>
#   <script src="http://www.acceptancerate.com/wp-content/plugins/cherry-plugin/lib/js/jquery.easing.1.3.js?ver=1.3" type="text/javascript">
#   </script>
#   <script src="http://www.acceptancerate.com/wp-content/plugins/cherry-plugin/lib/js/elasti-carousel/jquery.elastislide.js?ver=1.2.8.1" type="text/javascript">
#   </script>
#   <script src="//maps.googleapis.com/maps/api/js?v=3.exp&amp;sensor=false&amp;ver=4.3.11" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var thumbs_rating_ajax={"ajax_url":"http:\/\/www.acceptancerate.com\/wp-admin\/admin-ajax.php"};
#   </script>
#   <script src="http://www.acceptancerate.com/wp-content/themes/CherryFramework/js/jquery-migrate-1.2.1.min.js?ver=1.2.1" type="text/javascript">
#   </script>
#   <link href="http://www.acceptancerate.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
#   <link href="http://www.acceptancerate.com/wp-includes/wlwmanifest.xml" rel="wlwmanifest" type="application/wlwmanifest+xml"/>
#   <meta content="WordPress 4.3.11" name="generator">
#    <link href="http://www.acceptancerate.com/california" rel="canonical"/>
#    <link href="http://www.acceptancerate.com/?p=1984" rel="shortlink"/>
#    <script>
#     var system_folder='http://www.acceptancerate.com/wp-content/themes/CherryFramework/admin/data_management/',CHILD_URL='http://www.acceptancerate.com/wp-content/themes/Child-Theme',PARENT_URL='http://www.acceptancerate.com/wp-content/themes/CherryFramework',CURRENT_THEME='child_theme'
#    </script>
#    <link href="https://plus.google.com/112891675583279231101" rel="author"/>
#    <style type="text/css">
#     .recentcomments a{display:inline !important;padding:0 !important;margin:0 !important}
#    </style>
#    <style type="text/css">
#     h1{font:normal 46px/49px Droid Serif;color:#444}h2{font:normal 22px/22px Open Sans;color:#000}h3{font:normal 18px/22px Open Sans;color:#000}h4{font:bold 14px/22px Open Sans;color:#000}h5{font:bold 14px/22px Open Sans;color:#000}h6{font:normal 12px/18px Arial,Helvetica,sans-serif;color:#333}body{font-weight:normal}.logo_h__txt,.logo_link{font:bold 24px/20px Open Sans;color:#444}.sf-menu>li>a{font:bold 16px/19px Open Sans;color:#AAA}.nav.footer-nav a{font:bold 14px/19px Open Sans;color:#cfcfcf}
#    </style>
#    <!--[if lt IE 8]><div style=' clear: both; text-align:center; position: relative;'> <a href="http://www.microsoft.com/windows/internet-explorer/default.aspx?ocid=ie6_countdown_bannercode"><img src="http://storage.ie6countdown.com/assets/100/images/banners/warning_bar_0000_us.jpg" border="0" alt="" /></a></div> <![endif]-->
#    <!--[if (gt IE 9)|!(IE)]><!-->
#    <script type="text/javascript">
#     jQuery(function(){jQuery('.sf-menu').mobileMenu({defaultText:"Navigate to..."});});
#    </script>
#    <!--<![endif]-->
#    <script type="text/javascript">
#     /*<![CDATA[*/jQuery(function(){jQuery('ul.sf-menu').superfish({delay:200,animation:{opacity:"false",height:"show"},speed:"normal",autoArrows:false,disableHI:true});var viewportmeta=document.querySelector&&document.querySelector('meta[name="viewport"]'),ua=navigator.userAgent,gestureStart=function(){viewportmeta.content="width=device-width, minimum-scale=0.25, maximum-scale=1.6, initial-scale=1.0";},scaleFix=function(){if(viewportmeta&&/iPhone|iPad/.test(ua)&&!/Opera Mini/.test(ua)){viewportmeta.content="width=device-width, minimum-scale=1.0, maximum-scale=1.0";document.addEventListener("gesturestart",gestureStart,false);}};scaleFix();})/*]]>*/
#    </script>
#   </meta>
#  </head>
#  <body class="page page-id-1984 page-template page-template-page-state page-template-page-state-php">
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');ga('create','UA-48789805-1','acceptancerate.com');ga('require','displayfeatures');ga('send','pageview');
#   </script>
#   <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-5407ec4a45bbc8d0" type="text/javascript">
#   </script>
#   <div class="main-holder" id="motopress-main">
#    <header class="motopress-wrapper header">
#     <div class="container">
#      <div class="row">
#       <div class="span12" data-motopress-id="598e1924a4f8b" data-motopress-wrapper-file="wrapper/wrapper-header.php" data-motopress-wrapper-type="header">
#        <div class="row">
#         <div class="span12 hidden-phone" data-motopress-static-file="static/static-search.php" data-motopress-type="static">
#         </div>
#         <div class="span3" data-motopress-static-file="static/static-logo.php" data-motopress-type="static">
#          <div class="logo">
#           <a class="logo_h logo_h__img" href="http://www.acceptancerate.com/">
#            <img alt="AcceptanceRate.com" src="http://www.acceptancerate.com/wp-content/uploads/2014/03/ar_logo.gif" title=""/>
#           </a>
#           <p class="logo_tagline">
#           </p>
#          </div>
#         </div>
#         <div class="nav-holder" data-motopress-static-file="static/static-nav.php" data-motopress-type="static">
#          <nav class="nav nav__primary clearfix">
#           <ul class="sf-menu" id="topnav">
#            <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480727" id="menu-item-480727">
#             <a href="http://www.acceptancerate.com/">
#              Home
#             </a>
#            </li>
#            <li class="menu-item menu-item-type-custom menu-item-object-custom current-menu-ancestor current-menu-parent menu-item-has-children menu-item-480728" id="menu-item-480728">
#             <a href="#">
#              Browse By State
#             </a>
#             <ul class="sub-menu">
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480729" id="menu-item-480729">
#               <a href="http://www.acceptancerate.com/alabama">
#                Alabama
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480730" id="menu-item-480730">
#               <a href="http://www.acceptancerate.com/alaska">
#                Alaska
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480731" id="menu-item-480731">
#               <a href="http://www.acceptancerate.com/arizona">
#                Arizona
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480732" id="menu-item-480732">
#               <a href="http://www.acceptancerate.com/arkansas">
#                Arkansas
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page current-menu-item page_item page-item-1984 current_page_item menu-item-480733" id="menu-item-480733">
#               <a href="http://www.acceptancerate.com/california">
#                California
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480734" id="menu-item-480734">
#               <a href="http://www.acceptancerate.com/colorado">
#                Colorado
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480735" id="menu-item-480735">
#               <a href="http://www.acceptancerate.com/connecticut">
#                Connecticut
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480737" id="menu-item-480737">
#               <a href="http://www.acceptancerate.com/delaware">
#                Delaware
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480740" id="menu-item-480740">
#               <a href="http://www.acceptancerate.com/florida">
#                Florida
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480741" id="menu-item-480741">
#               <a href="http://www.acceptancerate.com/georgia">
#                Georgia
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480742" id="menu-item-480742">
#               <a href="http://www.acceptancerate.com/hawaii">
#                Hawaii
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480743" id="menu-item-480743">
#               <a href="http://www.acceptancerate.com/idaho">
#                Idaho
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480862" id="menu-item-480862">
#               <a href="http://www.acceptancerate.com/illinois">
#                Illinois
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480744" id="menu-item-480744">
#               <a href="http://www.acceptancerate.com/indiana">
#                Indiana
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480745" id="menu-item-480745">
#               <a href="http://www.acceptancerate.com/iowa">
#                Iowa
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480861" id="menu-item-480861">
#               <a href="http://www.acceptancerate.com/kansas">
#                Kansas
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480746" id="menu-item-480746">
#               <a href="http://www.acceptancerate.com/kentucky">
#                Kentucky
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480747" id="menu-item-480747">
#               <a href="http://www.acceptancerate.com/louisiana">
#                Louisiana
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480748" id="menu-item-480748">
#               <a href="http://www.acceptancerate.com/maine">
#                Maine
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480749" id="menu-item-480749">
#               <a href="http://www.acceptancerate.com/maryland">
#                Maryland
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480750" id="menu-item-480750">
#               <a href="http://www.acceptancerate.com/massachusetts">
#                Massachusetts
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480751" id="menu-item-480751">
#               <a href="http://www.acceptancerate.com/michigan">
#                Michigan
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480752" id="menu-item-480752">
#               <a href="http://www.acceptancerate.com/minnesota">
#                Minnesota
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480753" id="menu-item-480753">
#               <a href="http://www.acceptancerate.com/mississippi">
#                Mississippi
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480754" id="menu-item-480754">
#               <a href="http://www.acceptancerate.com/missouri">
#                Missouri
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480755" id="menu-item-480755">
#               <a href="http://www.acceptancerate.com/montana">
#                Montana
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480756" id="menu-item-480756">
#               <a href="http://www.acceptancerate.com/nebraska">
#                Nebraska
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480757" id="menu-item-480757">
#               <a href="http://www.acceptancerate.com/nevada">
#                Nevada
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480758" id="menu-item-480758">
#               <a href="http://www.acceptancerate.com/new-hampshire">
#                New Hampshire
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480759" id="menu-item-480759">
#               <a href="http://www.acceptancerate.com/new-jersey">
#                New Jersey
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480760" id="menu-item-480760">
#               <a href="http://www.acceptancerate.com/new-mexico">
#                New Mexico
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480761" id="menu-item-480761">
#               <a href="http://www.acceptancerate.com/new-york">
#                New York
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480762" id="menu-item-480762">
#               <a href="http://www.acceptancerate.com/north-carolina">
#                North Carolina
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480763" id="menu-item-480763">
#               <a href="http://www.acceptancerate.com/north-dakota">
#                North Dakota
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480764" id="menu-item-480764">
#               <a href="http://www.acceptancerate.com/ohio">
#                Ohio
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480765" id="menu-item-480765">
#               <a href="http://www.acceptancerate.com/oklahoma">
#                Oklahoma
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480766" id="menu-item-480766">
#               <a href="http://www.acceptancerate.com/oregon">
#                Oregon
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480768" id="menu-item-480768">
#               <a href="http://www.acceptancerate.com/pennsylvania">
#                Pennsylvania
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480770" id="menu-item-480770">
#               <a href="http://www.acceptancerate.com/rhode-island">
#                Rhode Island
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480773" id="menu-item-480773">
#               <a href="http://www.acceptancerate.com/south-carolina">
#                South Carolina
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480774" id="menu-item-480774">
#               <a href="http://www.acceptancerate.com/south-dakota">
#                South Dakota
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480775" id="menu-item-480775">
#               <a href="http://www.acceptancerate.com/tennessee">
#                Tennessee
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480776" id="menu-item-480776">
#               <a href="http://www.acceptancerate.com/texas">
#                Texas
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480777" id="menu-item-480777">
#               <a href="http://www.acceptancerate.com/utah">
#                Utah
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480778" id="menu-item-480778">
#               <a href="http://www.acceptancerate.com/vermont">
#                Vermont
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480779" id="menu-item-480779">
#               <a href="http://www.acceptancerate.com/virginia">
#                Virginia
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480780" id="menu-item-480780">
#               <a href="http://www.acceptancerate.com/washington">
#                Washington
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480781" id="menu-item-480781">
#               <a href="http://www.acceptancerate.com/west-virginia">
#                West Virginia
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480782" id="menu-item-480782">
#               <a href="http://www.acceptancerate.com/wisconsin">
#                Wisconsin
#               </a>
#              </li>
#              <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480783" id="menu-item-480783">
#               <a href="http://www.acceptancerate.com/wyoming">
#                Wyoming
#               </a>
#              </li>
#             </ul>
#            </li>
#            <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-480785" id="menu-item-480785">
#             <a href="http://www.acceptancerate.com/search">
#              Search for Colleges
#             </a>
#            </li>
#            <li class="menu-item menu-item-type-post_type menu-item-object-page menu-item-480786" id="menu-item-480786">
#             <a href="http://www.acceptancerate.com/about">
#              Our Experts
#             </a>
#            </li>
#           </ul>
#          </nav>
#         </div>
#         <div class="social-nets-wrapper" data-motopress-static-file="static/static-social-networks.php" data-motopress-type="static">
#          <ul class="social">
#           <li>
#            <a href="https://twitter.com/AcceptanceRate" target="_blank" title="Twitter">
#             <i class="icon-twitter">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="https://www.facebook.com/acceptancerate" target="_blank" title="Facebook">
#             <i class="icon-facebook">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="https://plus.google.com/110806283374075043690" target="_blank" title="Google-Plus">
#             <i class="icon-google-plus">
#             </i>
#            </a>
#           </li>
#           <li>
#            <a href="http://www.pinterest.com/acceptancerate" target="_blank" title="Pinterest">
#             <i class="icon-pinterest">
#             </i>
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#    <div class="header_top_bar">
#    </div>
#    <div class="motopress-wrapper content-holder clearfix">
#     <div class="container">
#      <div class="row">
#       <div class="span12" data-motopress-static-file="static/static-title.php" data-motopress-type="static">
#        <div class="spacer">
#        </div>
#        <h1>
#         California College &amp; University Acceptance Rates
#        </h1>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="motopress-wrapper content-holder clearfix">
#     <div class="container">
#      <div class="row">
#       <div class="span12 post_content main_content" data-motopress-wrapper-file="page-home.php" data-motopress-wrapper-type="content">
#        <table class="table table-hover table-condensed listing_table" id="school_listings">
#         <thead>
#          <tr>
#           <th class="hidden-phone">
#           </th>
#           <th style="width:50%;">
#            School Name
#           </th>
#           <th class="hidden-phone">
#            Applicants
#           </th>
#           <th class="hidden-phone">
#            Admitted
#           </th>
#           <th id="acceptance_rate_header">
#            Acceptance Rate
#           </th>
#          </tr>
#         </thead>
#         <tbody>
#          <tr data-act="31-34" data-gpa="3.90-4" data-sat="2070-2350" data-size="4" id="id_243744" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-243744"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/stanford-university">
#              Stanford University
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             Address Unknown, Stanford, CA 94305
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            38,828
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            2,208
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            5.7%
#           </td>
#          </tr>
#          <tr data-act="33-35" data-gpa="4-4" data-sat="2210-2390" data-size="2" id="id_110404" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-110404"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/california-institute-of-technology">
#              California Institute of Technology (Caltech)
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             1200 E California Blvd, Pasadena, CA 91125
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            5,535
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            584
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            10.6%
#           </td>
#          </tr>
#          <tr data-act="29-33" data-gpa="3.75-3.96" data-sat="1980-2250" data-size="2" id="id_112260" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-112260"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/claremont-mckenna-college">
#              Claremont McKenna College
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             500 E 9th St, Claremont, CA 91711-6400
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            5,518
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            647
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            11.7%
#           </td>
#          </tr>
#          <tr data-act="31-34" data-gpa="3.90-4" data-sat="2070-2320" data-size="2" id="id_121345" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-121345"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/pomona-college">
#              Pomona College
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             550 N College Ave, Claremont, CA 91711-6319
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            7,153
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            996
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            13.9%
#           </td>
#          </tr>
#          <tr data-act="-" data-gpa="-" data-sat="-" data-size="2" id="id_121257" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-121257"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/pitzer-college">
#              Pitzer College
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             1050 North Mills Avenue, Claremont, CA 91711-6101
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            4,115
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            597
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            14.5%
#           </td>
#          </tr>
#          <tr data-act="27-33" data-gpa="3.62-3.96" data-sat="1840-2240" data-size="5" id="id_110635" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-110635"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/university-of-california-berkeley">
#              University of California-Berkeley (UC Berkeley)
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             200 California Hall, Berkeley, CA 94720
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            61,717
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            11,108
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            18.0%
#           </td>
#          </tr>
#          <tr data-act="32-35" data-gpa="3.90-4" data-sat="2070-2320" data-size="1" id="id_115409" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-115409"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/harvey-mudd-college">
#              Harvey Mudd College (HMC)
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             301 Platt Blvd., Claremont, CA 91711
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            3,539
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            643
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            18.2%
#           </td>
#          </tr>
#          <tr data-act="29-33" data-gpa="3.68-3.96" data-sat="1920-2230" data-size="5" id="id_123961" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-123961"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/university-of-southern-california">
#              University of Southern California (USC)
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             University Park, Los Angeles, CA 90089
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            47,358
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            9,395
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            19.8%
#           </td>
#          </tr>
#          <tr data-act="25-31" data-gpa="3.48-3.89" data-sat="1750-2150" data-size="5" id="id_110662" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-110662"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/university-of-california-los-angeles">
#              University of California-Los Angeles (UCLA)
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             405 Hilgard Ave, Los Angeles, CA 90095-1405
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            72,676
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            15,981
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            22.0%
#           </td>
#          </tr>
#          <tr data-act="-" data-gpa="-" data-sat="-" data-size="2" id="id_111081" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-111081"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/california-institute-of-the-arts">
#              California Institute of the Arts (CalArts)
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             24700 W McBean Pky, Valencia, CA 91355-2397
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            1,230
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            368
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            29.9%
#           </td>
#          </tr>
#          <tr data-act="18-24" data-gpa="2.89-3.25" data-sat="-" data-size="5" id="id_110583" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-110583"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/california-state-university-long-beach">
#              California State University-Long Beach (CSULB)
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             1250 Bellflower Blvd, Long Beach, CA 90840-0115
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            55,019
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            16,956
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            30.8%
#           </td>
#          </tr>
#          <tr data-act="21-26" data-gpa="3.13-3.38" data-sat="-" data-size="5" id="id_122409" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-122409"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/san-diego-state-university">
#              San Diego State University (SDSU)
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             5500 Campanile Dr, San Diego, CA 92182
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            51,163
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            15,970
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            31.2%
#           </td>
#          </tr>
#          <tr data-act="25-30" data-gpa="3.42-3.64" data-sat="-" data-size="4" id="id_110422" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-110422"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/california-polytechnic-state-university-san-luis-obispo">
#              California Polytechnic State University-San Luis Obispo (Cal Poly)
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             1 Grand Ave., San Luis Obispo, CA 93407
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            36,941
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            11,537
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            31.2%
#           </td>
#          </tr>
#          <tr data-act="29-32" data-gpa="3.75-3.96" data-sat="1940-2203" data-size="2" id="id_123165" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-image_not_available.jpg"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/scripps-college">
#              Scripps College
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             1030 North Columbia Avenue, Claremont, CA 91711-3905
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            2,378
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            849
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            35.7%
#           </td>
#          </tr>
#          <tr data-act="19-25" data-gpa="2.98-3.25" data-sat="1307-1610" data-size="1" id="id_118693" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-118693"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/menlo-college">
#              Menlo College
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             1000 El Camino Real, Atherton, CA 94027-4301
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            4,100
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            1,519
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            37.0%
#           </td>
#          </tr>
#          <tr data-act="25-31" data-gpa="3.48-3.78" data-sat="1750-2080" data-size="5" id="id_110680" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-110680"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/university-of-california-san-diego">
#              University of California-San Diego (UCSD)
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             9500 Gilman Dr, La Jolla, CA 92093
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            60,832
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            22,812
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            37.5%
#           </td>
#          </tr>
#          <tr data-act="-" data-gpa="3.42-3.71" data-sat="1700-2010" data-size="3" id="id_121150" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-121150"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/pepperdine-university">
#              Pepperdine University
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             24255 Pacific Coast Hwy, Malibu, CA 90263
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            9,721
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            3,630
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            37.3%
#           </td>
#          </tr>
#          <tr data-act="20-25" data-gpa="3.06-3.33" data-sat="1390-1690" data-size="3" id="id_117140" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-117140"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/university-of-la-verne">
#              University of La Verne
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             1950 Third St, La Verne, CA 91750-4401
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            6,989
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            2,722
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            38.9%
#           </td>
#          </tr>
#          <tr data-act="-" data-gpa="-" data-sat="-" data-size="1" id="id_122506" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-image_not_available.jpg"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/san-francisco-conservatory-of-music">
#              San Francisco Conservatory of Music
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             50 Oak Street, San Francisco, CA 94102-6011
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            296
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            118
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            39.9%
#           </td>
#          </tr>
#          <tr data-act="21-27" data-gpa="3.13-3.57" data-sat="1480-1890" data-size="5" id="id_110653" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-110653"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/university-of-california-irvine">
#              University of California-Irvine (UCI)
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             501 Aldrich Hall, Irvine, CA 92697
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            56,515
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            23,956
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            42.4%
#           </td>
#          </tr>
#          <tr data-act="27-31" data-gpa="3.55-3.78" data-sat="1820-2100" data-size="2" id="id_120254" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-120254"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/occidental-college">
#              Occidental College (OXY)
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             1600 Campus Rd, Los Angeles, CA 90041-3392
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            6,072
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            2,574
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            42.4%
#           </td>
#          </tr>
#          <tr data-act="-" data-gpa="-" data-sat="-" data-size="1" id="id_117168" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-image_not_available.jpg"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/laguna-college-of-art-and-design">
#              Laguna College of Art and Design
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             2222 Laguna Canyon Rd, Laguna Beach, CA 92651
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            490
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            212
#           </td>
#           <td class="fs26 vertical_align_middle pbox10">
#            43.3%
#           </td>
#          </tr>
#          <tr data-act="25-29" data-gpa="3.35-3.64" data-sat="1620-1970" data-size="1" id="id_399911" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
#           <td class="hidden-phone vertical_align_middle">
#            <img src="http://www.acceptancerate.com/images/schools/tn_w100-h75-399911"/>
#           </td>
#           <td class="pB20">
#            <span class="name fs20" itemprop="name">
#             <a href="schools/soka-university-of-america">
#              Soka University of America
#             </a>
#            </span>
#            <br/>
#            <span class="fs12 light_text address" itemprop="address">
#             1 University Drive, Aliso Viejo, CA 92656-4105
#            </span>
#           </td>
#           <td class="fs20 hidden-phone vertical_align_middle">
#            422
#           </td>
# ...
#           </a>
#          </div>
#         </div>
#         <div class="span12 copyright-widget" data-motopress-sidebar-id="footer-sidebar-5" data-motopress-type="dynamic-sidebar">
#         </div>
#         <div class="span12 copyright-text" data-motopress-static-file="static/static-footer-text.php" data-motopress-type="static">
#          <div class="footer-text" id="footer-text">
#           AcceptanceRate.com © 2017 |
#           <a href="http://www.acceptancerate.com/privacy-policy" title="Privacy Policy">
#            Privacy Policy
#           </a>
#           |
#           <a href="http://www.acceptancerate.com/about" title="About Us">
#            Our Experts &amp; About Us
#           </a>
#           |
#           <a href="http://www.acceptancerate.com/contact-us" title="Contact Us">
#            Contact Us
#           </a>
#          </div>
#         </div>
#         <div class="span12" data-motopress-static-file="static/static-footer-nav.php" data-motopress-type="static">
#         </div>
#         <div class="clear">
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <div class="visible-desktop" id="back-top-wrapper">
#    <p id="back-top">
#     <a href="#top">
#      <span>
#      </span>
#     </a>
#    </p>
#   </div>
#   <script>
#    jQuery(document).ready(function(){jQuery(".thumbs-rating-container").each(function(index){var content_id=jQuery(this).data('content-id');var itemName="thumbsrating"+content_id;if(localStorage.getItem(itemName)){if(localStorage.getItem("thumbsrating"+content_id+"-1")){jQuery(this).find('.thumbs-rating-up').addClass('thumbs-rating-voted');}
# if(localStorage.getItem("thumbsrating"+content_id+"-0")){jQuery(this).find('.thumbs-rating-down').addClass('thumbs-rating-voted');}}});});
#   </script>
#   <script type="text/javascript">
#    var items_custom=[[0,1],[480,2],[768,3],[980,4],[1170,5]];
#   </script>
#   <script type="text/javascript">
#    var _wpcf7={"loaderUrl":"http:\/\/www.acceptancerate.com\/wp-content\/plugins\/contact-form-7\/images\/ajax-loader.gif","sending":"Sending ...","cached":"1"};
#   </script>
#   <script src="http://www.acceptancerate.com/wp-content/themes/CherryFramework/js/tmstickup.js?ver=1.0.0" type="text/javascript">
#   </script>
#   <script src="http://www.acceptancerate.com/wp-content/themes/CherryFramework/js/device.min.js?ver=1.0.0" type="text/javascript">
#   </script>
#   <script src="http://www.acceptancerate.com/wp-content/themes/CherryFramework/js/camera.min.js?ver=1.3.4" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    deleteCookie('cf-cookie-banner');
#   </script>
#   <script src="http://www.acceptancerate.com/wp-content/cache/minify/000000/a8ca8/default.include-footer.1a420c.js" type="text/javascript">
#   </script>
#  </body>
# </html>
#  School NameApplicantsAdmittedAcceptance RateStanford UniversityAddress Unknown, Stanford, CA 9430538,8282,2085.7%California Institute of Technology (Caltech)1200 E California Blvd, Pasadena, CA 911255,53558410.6%Claremont McKenna College500 E 9th St, Claremont, CA 91711-64005,51864711.7%Pomona College550 N College Ave, Claremont, CA 91711-63197,15399613.9%Pitzer College1050 North Mills Avenue, Claremont, CA 91711-61014,11559714.5%University of California-Berkeley (UC Berkeley)200 California Hall, Berkeley, CA 9472061,71711,10818.0%Harvey Mudd College (HMC)301 Platt Blvd., Claremont, CA 917113,53964318.2%University of Southern California (USC)University Park, Los Angeles, CA 9008947,3589,39519.8%University of California-Los Angeles (UCLA)405 Hilgard Ave, Los Angeles, CA 90095-140572,67615,98122.0%California Institute of the Arts (CalArts)24700 W McBean Pky, Valencia, CA 91355-23971,23036829.9%California State University-Long Beach (CSULB)1250 Bellflower Blvd, Long Beach, CA 90840-011555,01916,95630.8%San Diego State University (SDSU)5500 Campanile Dr, San Diego, CA 9218251,16315,97031.2%California Polytechnic State University-San Luis Obispo (Cal Poly)1 Grand Ave., San Luis Obispo, CA 9340736,94111,53731.2%Scripps College1030 North Columbia Avenue, Claremont, CA 91711-39052,37884935.7%Menlo College1000 El Camino Real, Atherton, CA 94027-43014,1001,51937.0%University of California-San Diego (UCSD)9500 Gilman Dr, La Jolla, CA 9209360,83222,81237.5%Pepperdine University24255 Pacific Coast Hwy, Malibu, CA 902639,7213,63037.3%University of La Verne1950 Third St, La Verne, CA 91750-44016,9892,72238.9%San Francisco Conservatory of Music50 Oak Street, San Francisco, CA 94102-601129611839.9%University of California-Irvine (UCI)501 Aldrich Hall, Irvine, CA 9269756,51523,95642.4%Occidental College (OXY)1600 Campus Rd, Los Angeles, CA 90041-33926,0722,57442.4%Laguna College of Art and Design2222 Laguna Canyon Rd, Laguna Beach, CA 9265149021243.3%Soka University of America1 University Drive, Aliso Viejo, CA 92656-410542218343.4%California State University-Monterey Bay (CSUMB)100 Campus Center, Seaside, CA 93955-800112,5625,57744.4%University of California-Santa Barbara (UCSB)5221 Cheadle Hall, Santa Barbara, CA 9310655,25824,55644.4%Chapman UniversityOne University Dr., Orange, CA 9286611,7505,25344.7%University of California-Davis (UC Davis)One Shields Avenue, Davis, CA 95616-867849,82022,52645.2%California State University-Fullerton (CSUF)800 N State College Blvd, Fullerton, CA 92831-359938,90917,81745.8%California State University-Northridge (CSUN)18111 Nordhoff St, Northridge, CA 9133029,33913,56646.2%Otis College of Art and Design (Otis Art Institute)9045 Lincoln Blvd, Los Angeles, CA 90045-35051,58473346.3%La Sierra University4500 Riverwalk Parkway, Riverside, CA 92515-82473,4791,62746.8%Hope International University (Hope)2500 E Nutwood Ave, Fullerton, CA 92831-319940819146.8%California Lutheran University (CLU)60 W Olsen Rd, Thousand Oaks, CA 91360-27876,9203,32348.0%University of San Diego (USD)5998 Alcala Park, San Diego, CA 92110-249214,6937,17848.9%San Diego Christian College2100 Greenfield Dr, El Cajon, CA 92019-115756127649.2%Pacific Union College (PUC)One Angwin Ave, Angwin, CA 94508-97072,1031,06350.5%Santa Clara University (SCU)500 El Camino Real, Santa Clara, CA 9505314,3397,34451.2%California State Polytechnic University-Pomona (Cal Poly Pomona)3801 West Temple Avenue, Pomona, CA 9176828,14314,68652.2%Columbia College Hollywood18618 Oxnard St, Tarzana, CA 91356-141125013754.8%Loyola Marymount University (LMU)One Lmu Drive, Los Angeles, CA 90045-265911,4726,20954.1%Simpson University (Simpson College)2211 College View Drive, Redding, CA 96003-860657331855.5%Woodbury University7500 Glenoaks Blvd, Burbank, CA 91510-784687949055.7%Holy Names University3500 Mountain Blvd, Oakland, CA 94619-169956131856.7%California State University-Dominguez Hills (CSUDH)1000 E Victoria St, Carson, CA 90747-000514,7428,47257.5%California Stat ...
# ('Stanford UniversityAddress Unknown, Stanford, CA 94305', '38,828', '2,208', '5.7%')
# ('California Institute of Technology (Caltech)1200 E California Blvd, Pasadena, CA 91125', '5,535', '584', '10.6%')
# ('Claremont McKenna College500 E 9th St, Claremont, CA 91711-6400', '5,518', '647', '11.7%')
# ('Pomona College550 N College Ave, Claremont, CA 91711-6319', '7,153', '996', '13.9%')
# ('Pitzer College1050 North Mills Avenue, Claremont, CA 91711-6101', '4,115', '597', '14.5%')
# ('University of California-Berkeley (UC Berkeley)200 California Hall, Berkeley, CA 94720', '61,717', '11,108', '18.0%')
# ('Harvey Mudd College (HMC)301 Platt Blvd., Claremont, CA 91711', '3,539', '643', '18.2%')
# ('University of Southern California (USC)University Park, Los Angeles, CA 90089', '47,358', '9,395', '19.8%')
# ('University of California-Los Angeles (UCLA)405 Hilgard Ave, Los Angeles, CA 90095-1405', '72,676', '15,981', '22.0%')
# ('California Institute of the Arts (CalArts)24700 W McBean Pky, Valencia, CA 91355-2397', '1,230', '368', '29.9%')
# ('California State University-Long Beach (CSULB)1250 Bellflower Blvd, Long Beach, CA 90840-0115', '55,019', '16,956', '30.8%')
# ('San Diego State University (SDSU)5500 Campanile Dr, San Diego, CA 92182', '51,163', '15,970', '31.2%')
# ('California Polytechnic State University-San Luis Obispo (Cal Poly)1 Grand Ave., San Luis Obispo, CA 93407', '36,941', '11,537', '31.2%')
# ('Scripps College1030 North Columbia Avenue, Claremont, CA 91711-3905', '2,378', '849', '35.7%')
# ('Menlo College1000 El Camino Real, Atherton, CA 94027-4301', '4,100', '1,519', '37.0%')
# ('University of California-San Diego (UCSD)9500 Gilman Dr, La Jolla, CA 92093', '60,832', '22,812', '37.5%')
# ('Pepperdine University24255 Pacific Coast Hwy, Malibu, CA 90263', '9,721', '3,630', '37.3%')
# ('University of La Verne1950 Third St, La Verne, CA 91750-4401', '6,989', '2,722', '38.9%')
# ('San Francisco Conservatory of Music50 Oak Street, San Francisco, CA 94102-6011', '296', '118', '39.9%')
# ('University of California-Irvine (UCI)501 Aldrich Hall, Irvine, CA 92697', '56,515', '23,956', '42.4%')
# ('Occidental College (OXY)1600 Campus Rd, Los Angeles, CA 90041-3392', '6,072', '2,574', '42.4%')
# ('Laguna College of Art and Design2222 Laguna Canyon Rd, Laguna Beach, CA 92651', '490', '212', '43.3%')
# ('Soka University of America1 University Drive, Aliso Viejo, CA 92656-4105', '422', '183', '43.4%')
# ('California State University-Monterey Bay (CSUMB)100 Campus Center, Seaside, CA 93955-8001', '12,562', '5,577', '44.4%')
# ('University of California-Santa Barbara (UCSB)5221 Cheadle Hall, Santa Barbara, CA 93106', '55,258', '24,556', '44.4%')
# ('Chapman UniversityOne University Dr., Orange, CA 92866', '11,750', '5,253', '44.7%')
# ('University of California-Davis (UC Davis)One Shields Avenue, Davis, CA 95616-8678', '49,820', '22,526', '45.2%')
# ('California State University-Fullerton (CSUF)800 N State College Blvd, Fullerton, CA 92831-3599', '38,909', '17,817', '45.8%')
# ('California State University-Northridge (CSUN)18111 Nordhoff St, Northridge, CA 91330', '29,339', '13,566', '46.2%')
# ('Otis College of Art and Design (Otis Art Institute)9045 Lincoln Blvd, Los Angeles, CA 90045-3505', '1,584', '733', '46.3%')
# ('La Sierra University4500 Riverwalk Parkway, Riverside, CA 92515-8247', '3,479', '1,627', '46.8%')
# ('Hope International University (Hope)2500 E Nutwood Ave, Fullerton, CA 92831-3199', '408', '191', '46.8%')
# ('California Lutheran University (CLU)60 W Olsen Rd, Thousand Oaks, CA 91360-2787', '6,920', '3,323', '48.0%')
# ('University of San Diego (USD)5998 Alcala Park, San Diego, CA 92110-2492', '14,693', '7,178', '48.9%')
# ('San Diego Christian College2100 Greenfield Dr, El Cajon, CA 92019-1157', '561', '276', '49.2%')
# ('Pacific Union College (PUC)One Angwin Ave, Angwin, CA 94508-9707', '2,103', '1,063', '50.5%')
# ('Santa Clara University (SCU)500 El Camino Real, Santa Clara, CA 95053', '14,339', '7,344', '51.2%')
# ('California State Polytechnic University-Pomona (Cal Poly Pomona)3801 West Temple Avenue, Pomona, CA 91768', '28,143', '14,686', '52.2%')
# ('Columbia College Hollywood18618 Oxnard St, Tarzana, CA 91356-1411', '250', '137', '54.8%')
# ('Loyola Marymount University (LMU)One Lmu Drive, Los Angeles, CA 90045-2659', '11,472', '6,209', '54.1%')
# ('Simpson University (Simpson College)2211 College View Drive, Redding, CA 96003-8606', '573', '318', '55.5%')
# ('Woodbury University7500 Glenoaks Blvd, Burbank, CA 91510-7846', '879', '490', '55.7%')
# ('Holy Names University3500 Mountain Blvd, Oakland, CA 94619-1699', '561', '318', '56.7%')
# ('California State University-Dominguez Hills (CSUDH)1000 E Victoria St, Carson, CA 90747-0005', '14,742', '8,472', '57.5%')
# ('California State University-Fresno (Fresno State)5241 N Maple Ave, Fresno, CA 93740', '16,242', '9,444', '58.1%')
# ('California State University-San Bernardino (CSUSB)5500 University Pky, San Bernardino, CA 92407-2397', '12,239', '7,137', '58.3%')
# ('University of California-Santa Cruz (UC Santa Cruz)1156 High St, Santa Cruz, CA 95064-1011', '33,137', '19,851', '59.9%')
# ('San Diego State University-Imperial Valley Campus720 Heber Ave, Calexico, CA 92231', '201', '122', '60.7%')
# ('University of San Francisco (USF)2130 Fulton St, San Francisco, CA 94117-1080', '14,808', '9,076', '61.3%')
# ("The Master's College and Seminary21726 Placerita Canyon Road, Santa Clarita, CA 91321-1200", '849', '521', '61.4%')
# ('University of California-Riverside (UCR)900 University Ave, Riverside, CA 92521', '30,391', '18,843', '62.0%')
# ('California State University-San Marcos (CSUSM)333 S Twin Oaks Valley Rd, San Marcos, CA 92096-0001', '10,208', '6,381', '62.5%')
# ('Whittier College13406 E Philadelphia Street, Whittier, CA 90601', '4,380', '2,771', '63.3%')
# ('San Jose State University (SJSU)1 Washington Sq, San Jose, CA 95192-0001', '25,155', '15,967', '63.5%')
# ('San Francisco State University (SFSU)1600 Holloway Ave, San Francisco, CA 94132', '31,462', '20,070', '63.8%')
# ('California State University-Channel Islands (CI)One University Dr, Camarillo, CA 93012', '6,960', '4,484', '64.4%')
# ('California State University-Bakersfield (CSUB)9001 Stockdale Hwy, Bakersfield, CA 93311-1099', '6,630', '4,393', '66.3%')
# ('Point Loma Nazarene University (PLNU)3900 Lomaland Dr, San Diego, CA 92106-2899', '3,138', '2,088', '66.5%')
# ('University of Redlands1200 E. Colton Ave, Redlands, CA 92373-0999', '4,668', '3,137', '67.2%')
# ('California State University-Los Angeles (Cal State LA)5151 State University Dr, Los Angeles, CA 90032', '27,321', '18,448', '67.5%')
# ('Mills College5000 MacArthur Blvd, Oakland, CA 94613', '1,827', '1,242', '68.0%')
# ('California State University-East Bay (CSUEB)25800 Carlos Bee Blvd, Hayward, CA 94542', '12,741', '8,756', '68.7%')
# ('William Jessup University (San Jose Christian College)333 Sunset Blvd., Rocklin, CA 95765-3707', '482', '334', '69.3%')
# ('Saint Marys College of California (SMC)1928 Saint Marys Road, Moraga, CA 94575', '4,864', '3,379', '69.5%')
# ('California State University-Sacramento (Sacramento State)6000 J St, Sacramento, CA 95819-2694', '19,702', '13,728', '69.7%')
# ('Vanguard University of Southern California55 Fair Dr, Costa Mesa, CA 92626', '1,495', '1,043', '69.8%')
# ('Westmont College955 La Paz Rd, Santa Barbara, CA 93108-1089', '2,145', '1,505', '70.2%')
# ('California State University-ChicoFirst and Normal Sts, Chico, CA 95929-0150', '17,215', '12,327', '71.6%')
# ('California State University-Stanislaus (CSU Stanislaus)One University Circle, Turlock, CA 95382-0299', '5,763', '4,158', '72.1%')
# ('University of the Pacific (UOP)3601 Pacific Ave, Stockton, CA 95211-0197', '14,222', '10,332', '72.6%')
# ('Biola University13800 Biola Ave, La Mirada, CA 90639-0001', '4,816', '3,509', '72.9%')
# ("Mount St. Mary's College12001 Chalon Rd, Los Angeles, CA 90049-1599", '2,316', '1,716', '74.1%')
# ('California Maritime Academy (CMA)200 Maritime Academy Dr, Vallejo, CA 94590', '893', '668', '74.8%')
# ('University of California-Merced (UCM)5200 North Lake Road, Merced, CA 95343-5603', '14,056', '10,613', '75.5%')
# ('Dominican University of California (DUofC)50 Acacia Ave, San Rafael, CA 94901-2298', '2,322', '1,800', '77.5%')
# ('Fresno Pacific University1717 S Chestnut Ave, Fresno, CA 93702-4709', '705', '553', '78.4%')
# ('California Baptist University (CBU)8432 Magnolia Ave, Riverside, CA 92504-3297', '3,853', '3,036', '78.8%')
# ('Azusa Pacific University (APU)901 E Alosta, Azusa, CA 91702-7000', '5,329', '4,255', '79.8%')
# ('Humboldt State University (HSU)1 Harpst Street, Arcata, CA 95521-8299', '9,978', '8,000', '80.2%')
# ('California College of the Arts (CCA)1111 Eighth Street, San Francisco, CA 94107-2247', '1,405', '1,146', '81.6%')
# ('Art Center College of Design1700 Lida St, Pasadena, CA 91103', '480', '392', '81.7%')
# ('Sonoma State University (SSU)1801 E Cotati Ave, Rohnert Park, CA 94928-3609', '13,142', '10,758', '81.9%')
# ('San Francisco Art Institute800 Chestnut St, San Francisco, CA 94133-2299', '416', '344', '82.7%')
# ('Notre Dame de Namur University (NDNU)1500 Ralston Ave, Belmont, CA 94002-1908', '1,922', '1,676', '87.2%')
# ('Concordia University-Irvine (Concordia University Irvine)1530 Concordia West, Irvine, CA 92612-3203', '2,055', '1,874', '91.2%')

# %% [markdown]
# Comparison between 3 Universities

# %%
req = requests.get('http://study.com/articles/Top_Ranked_School_for_Information_Technology_-_San_Jose_CA.html')

# %%
soup = BeautifulSoup(req.content, 'html.parser')

# %%
table = soup.find_all('table')[0]

# %%
rows = table.find_all('tr')[2:]

# %%
for row in rows:
    cols = row.find_all('td')

# %%
data = {
    'Category' : [],
    'Santa Clara University' : [],
    'San Jose State University' : [],
    'University of San Francisco' : []
}

# %%
for row in rows:
    cols = row.find_all('td')    
    data['Category'].append( cols[0].get_text() )
    data['Santa Clara University'].append( cols[1].get_text() )
    data['San Jose State University'].append( cols[2].get_text() )
    data['University of San Francisco'].append( cols[3].get_text() )

# %%
import pandas as pd;
compareData = pd.DataFrame( data )

# %%
compareData.to_csv("Compare.csv")
